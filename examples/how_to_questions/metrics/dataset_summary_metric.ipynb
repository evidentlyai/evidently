# %% [markdown]
# # Evidently Dataset Summary Metric

# %% [markdown]
# ## Prepare Data

# %%
import pandas as pd
import numpy as np

from sklearn.datasets import fetch_openml

# load "adult" dataset
data = fetch_openml(name='adult', version=2, as_frame='auto')
df = data.frame

# prepare target and prediction
df['target'] = df['education-num']
df['prediction'] = df['education-num'].values + np.random.normal(0, 6, df.shape[0])

# make reference and current datasets
reference_data = df[~df.education.isin(['Some-college', 'HS-grad', 'Bachelors'])]
current_data = df[df.education.isin(['Some-college', 'HS-grad', 'Bachelors'])]
current_data.head()
# Out:
#     age workclass    fnlwgt     education  education-num      marital-status  \
# 1  38.0   Private   89814.0       HS-grad            9.0  Married-civ-spouse
# 3  44.0   Private  160323.0  Some-college           10.0  Married-civ-spouse
# 4  18.0       NaN  103497.0  Some-college           10.0       Never-married
# 6  29.0       NaN  227026.0       HS-grad            9.0       Never-married
# 8  24.0   Private  369667.0  Some-college           10.0       Never-married
#
#           occupation relationship   race     sex  capital-gain  capital-loss  \
# 1    Farming-fishing      Husband  White    Male           0.0           0.0
# 3  Machine-op-inspct      Husband  Black    Male        7688.0           0.0
# 4                NaN    Own-child  White  Female           0.0           0.0
# 6                NaN    Unmarried  Black    Male           0.0           0.0
# 8      Other-service    Unmarried  White  Female           0.0           0.0
#
#    hours-per-week native-country  class  target  prediction
# 1            50.0  United-States  <=50K     9.0    0.678037
# 3            40.0  United-States   >50K    10.0   11.672529
# 4            30.0  United-States  <=50K    10.0    6.102067
# 6            40.0  United-States  <=50K     9.0   18.204328
# 8            40.0  United-States  <=50K    10.0    1.934995

# %% [markdown]
# ## How to use the metric

# %% [markdown]
# Look at overall datasets info

# %%
from evidently.report import Report
from evidently.metrics import DatasetSummaryMetric

report = Report(metrics=[DatasetSummaryMetric()])
report.run(current_data=current_data, reference_data=None)
report
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_e8303572c53c45ab9036e2cc2f63b5ff = {"name": "Report", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "64a1cacd-cf28-47ab-89a9-47a55c6c48e8", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Dataset Summary"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "table", "title": "", "size": 2, "id": "78643e4a-8651-4da6-b965-4f491cf00dc6", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": ["Value", "Count"], "data": [["target column", "target"], ["date column", "None"], ["number of columns", "17"], ["number of rows", "34687"], ["missing values", "4373"], ["categorical columns", "9"], ["numeric columns", "6"], ["datetime columns", "0"], ["empty columns", "0"], ["constant columns", "0"], ["almost constant features", "1"], ["duplicated columns", "0"], ["almost duplicated features", "1"]]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}]};
#     var additional_graphs_evidently_dashboard_e8303572c53c45ab9036e2cc2f63b5ff = {};
# </script>
# <script>
# function domReady(fn) {
#   // If we're early to the party
#   document.addEventListener("DOMContentLoaded", fn);
#   // If late; I mean on time.
#   if (document.readyState === "interactive" || document.readyState === "complete" ) {
#     fn();
#   }
# }
#
# domReady(function () {
#     requirejs(["evidently"], function(ev) {
#         drawDashboard(evidently_dashboard_e8303572c53c45ab9036e2cc2f63b5ff,
#         new Map(Object.entries(additional_graphs_evidently_dashboard_e8303572c53c45ab9036e2cc2f63b5ff)),
#         "root_evidently_dashboard_e8303572c53c45ab9036e2cc2f63b5ff");
#     },
#     function(err) {
#         $("#root_evidently_dashboard_e8303572c53c45ab9036e2cc2f63b5ff").innerHTML = "Failed to load";
#     })
# });
# </script>
# <div class="reset-this-parent" id="root_evidently_dashboard_e8303572c53c45ab9036e2cc2f63b5ff">Loading...</div>

# %%
report = Report(metrics=[DatasetSummaryMetric()])
report.run(current_data=current_data, reference_data=reference_data)
report
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_adfd211682d2475daf0290dc35ae9bca = {"name": "Report", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "dcddb9bc-e408-4768-9a72-aa26ea80fc72", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Dataset Summary"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "tabs", "title": "", "size": 2, "id": "7515d63c-b8d5-4540-9ed5-848083fdd85e", "details": "", "alertsPosition": null, "alertStats": null, "params": null, "insights": [], "alerts": [], "tabs": [{"id": "1d8a3941-9f8e-4983-a1e6-4195c6ea8720", "title": "Current dataset", "widget": {"type": "table", "title": "", "size": 2, "id": "0d973714-bc63-44c5-aa4d-6b354b99632b", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": ["Value", "Count"], "data": [["target column", "target"], ["date column", "None"], ["number of columns", "17"], ["number of rows", "34687"], ["missing values", "4373"], ["categorical columns", "9"], ["numeric columns", "6"], ["datetime columns", "0"], ["empty columns", "0"], ["constant columns", "0"], ["almost constant features", "1"], ["duplicated columns", "0"], ["almost duplicated features", "1"]]}, "insights": [], "additionalGraphs": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}}, {"id": "2b375582-6658-4b02-b9bd-0a2c2f365738", "title": "Reference dataset", "widget": {"type": "table", "title": "", "size": 2, "id": "205586f0-d6ac-4c23-a359-1757ef5f6b9a", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": ["Value", "Count"], "data": [["target column", "target"], ["date column", "None"], ["number of columns", "17"], ["number of rows", "14155"], ["missing values", "2092"], ["categorical columns", "9"], ["numeric columns", "6"], ["datetime columns", "0"], ["empty columns", "0"], ["constant columns", "0"], ["almost constant features", "0"], ["duplicated columns", "0"], ["almost duplicated features", "1"]]}, "insights": [], "additionalGraphs": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}}], "widgets": [], "pageSize": 5}]};
#     var additional_graphs_evidently_dashboard_adfd211682d2475daf0290dc35ae9bca = {};
# </script>
# <script>
# function domReady(fn) {
#   // If we're early to the party
#   document.addEventListener("DOMContentLoaded", fn);
#   // If late; I mean on time.
#   if (document.readyState === "interactive" || document.readyState === "complete" ) {
#     fn();
#   }
# }
#
# domReady(function () {
#     requirejs(["evidently"], function(ev) {
#         drawDashboard(evidently_dashboard_adfd211682d2475daf0290dc35ae9bca,
#         new Map(Object.entries(additional_graphs_evidently_dashboard_adfd211682d2475daf0290dc35ae9bca)),
#         "root_evidently_dashboard_adfd211682d2475daf0290dc35ae9bca");
#     },
#     function(err) {
#         $("#root_evidently_dashboard_adfd211682d2475daf0290dc35ae9bca").innerHTML = "Failed to load";
#     })
# });
# </script>
# <div class="reset-this-parent" id="root_evidently_dashboard_adfd211682d2475daf0290dc35ae9bca">Loading...</div>
