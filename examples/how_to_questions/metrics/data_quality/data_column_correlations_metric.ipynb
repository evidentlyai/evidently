# %% [markdown]
# # Evidently Column Correlations Metric

# %% [markdown]
# ## Prepare Data

# %%
import pandas as pd
import numpy as np

from sklearn.datasets import fetch_openml

# load "adult" dataset
data = fetch_openml(name='adult', version=2, as_frame='auto')
df = data.frame

# prepare target and prediction
df['target'] = df['education-num']
df['prediction'] = df['education-num'].values + np.random.normal(0, 6, df.shape[0])

# make reference and current datasets
reference_data = df[~df.education.isin(['Some-college', 'HS-grad', 'Bachelors'])]
current_data = df[df.education.isin(['Some-college', 'HS-grad', 'Bachelors'])]
current_data.head()
# Out:
#     age workclass    fnlwgt     education  education-num      marital-status  \
# 1  38.0   Private   89814.0       HS-grad            9.0  Married-civ-spouse
# 3  44.0   Private  160323.0  Some-college           10.0  Married-civ-spouse
# 4  18.0       NaN  103497.0  Some-college           10.0       Never-married
# 6  29.0       NaN  227026.0       HS-grad            9.0       Never-married
# 8  24.0   Private  369667.0  Some-college           10.0       Never-married
#
#           occupation relationship   race     sex  capital-gain  capital-loss  \
# 1    Farming-fishing      Husband  White    Male           0.0           0.0
# 3  Machine-op-inspct      Husband  Black    Male        7688.0           0.0
# 4                NaN    Own-child  White  Female           0.0           0.0
# 6                NaN    Unmarried  Black    Male           0.0           0.0
# 8      Other-service    Unmarried  White  Female           0.0           0.0
#
#    hours-per-week native-country  class  target  prediction
# 1            50.0  United-States  <=50K     9.0    5.572409
# 3            40.0  United-States   >50K    10.0    7.163783
# 4            30.0  United-States  <=50K    10.0   12.480482
# 6            40.0  United-States  <=50K     9.0   15.055739
# 8            40.0  United-States  <=50K    10.0    9.578698

# %% [markdown]
# ## Try To Use

# %% [markdown]
# With a category column

# %%
from evidently.report import Report
from evidently.metrics import ColumnCorrelationsMetric

report = Report(metrics=[ColumnCorrelationsMetric(column_name="workclass")])
report.run(current_data=current_data, reference_data=reference_data)
report
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_a4da6285640c40c9a47e6e79a736a030 = {"name": "Report", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "72ed64e0-de9a-4ead-873c-5ab1d7907302", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Correlations for column 'workclass'."}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "tabs", "title": "", "size": 2, "id": "186efad3-9ede-462e-9943-f9d14ebad97e", "details": "", "alertsPosition": null, "alertStats": null, "params": null, "insights": [], "alerts": [], "tabs": [{"id": "514cfb06-d6fd-47a6-8676-610a2ee6b989", "title": "Current", "widget": {"type": "big_graph", "title": "", "size": 2, "id": "e13fceac-c931-44c8-a03b-6ccd80934b08", "details": "", "alertsPosition": null, "alertStats": null, "params": {"data": [{"marker": {"color": "#ed0400"}, "name": "current", "orientation": "v", "x": ["class", "education", "marital-status", "native-country", "occupation", "race", "relationship", "sex"], "y": [0.14266158996682204, 0.08467904035991143, 0.07933466619660155, 0.043998426864484526, 0.22254668981231465, 0.06110191774926169, 0.0882064336591909, 0.1447442524818569], "type": "bar"}], "layout": {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}, "pattern": {"fillmode": "overlay", "size": 10, "solidity": 0.2}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}, "pattern": {"fillmode": "overlay", "size": 10, "solidity": 0.2}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"pattern": {"fillmode": "overlay", "size": 10, "solidity": 0.2}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0. ...

# %% [markdown]
# With a numerical column

# %%
from evidently.report import Report
from evidently.metrics import ColumnCorrelationsMetric

report = Report(metrics=[ColumnCorrelationsMetric(column_name="age")])
report.run(current_data=current_data, reference_data=reference_data)
report
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_086aee01ea014389948620a0e7a516ab = {"name": "Report", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "f0c439e2-9c66-47cf-96f0-1e6a3632b812", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Correlations for column 'age'."}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "tabs", "title": "", "size": 2, "id": "807e769c-8f21-49c6-8798-dfa5380f04ed", "details": "", "alertsPosition": null, "alertStats": null, "params": null, "insights": [], "alerts": [], "tabs": [{"id": "cf3a1983-6586-4099-bd95-cfd70821a92c", "title": "Current", "widget": {"type": "tabs", "title": "", "size": 2, "id": "86509242-ff01-4526-aa23-bfa30da7e0a1", "details": "", "alertsPosition": null, "alertStats": null, "params": null, "insights": [], "additionalGraphs": [], "alerts": [], "tabs": [{"id": "4284483b-8cc0-4bce-bd25-a9362020046f", "title": "age", "widget": {"type": "big_graph", "title": "", "size": 2, "id": "1626fcac-d3f6-4afa-80b3-33b77031dc68", "details": "", "alertsPosition": null, "alertStats": null, "params": {"data": [{"marker": {"color": "#ed0400"}, "name": "current", "orientation": "v", "x": ["capital-gain", "capital-loss", "education-num", "fnlwgt", "hours-per-week"], "y": [0.0709406236366172, 0.05733672232899024, 0.006739550097972386, -0.07225681979404673, 0.0589923826064934], "type": "bar"}], "layout": {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}, "pattern": {"fillmode": "overlay", "size": 10, "solidity": 0.2}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}, "pattern": {"fillmode": "overlay", "size": 10, "solidity": 0.2}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"pattern": {"fillmode": "overlay", "size": 10, "solidity": 0.2}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f9 ...
