# %% [markdown]
# # Evidently Data Integrity Metrics

# %% [markdown]
# ## Prepare Data

# %%
import pandas as pd
import numpy as np

from sklearn.datasets import fetch_openml

# load "adult" dataset
data = fetch_openml(name='adult', version=2, as_frame='auto')
df = data.frame

# prepare target and prediction
df['target'] = df['education-num']
df['prediction'] = df['education-num'].values + np.random.normal(0, 6, df.shape[0])

# make reference and current datasets
reference_data = df[~df.education.isin(['Some-college', 'HS-grad', 'Bachelors'])]
current_data = df[df.education.isin(['Some-college', 'HS-grad', 'Bachelors'])]
current_data.head()
# Out:
#     age workclass    fnlwgt     education  education-num      marital-status  \
# 1  38.0   Private   89814.0       HS-grad            9.0  Married-civ-spouse
# 3  44.0   Private  160323.0  Some-college           10.0  Married-civ-spouse
# 4  18.0       NaN  103497.0  Some-college           10.0       Never-married
# 6  29.0       NaN  227026.0       HS-grad            9.0       Never-married
# 8  24.0   Private  369667.0  Some-college           10.0       Never-married
#
#           occupation relationship   race     sex  capital-gain  capital-loss  \
# 1    Farming-fishing      Husband  White    Male           0.0           0.0
# 3  Machine-op-inspct      Husband  Black    Male        7688.0           0.0
# 4                NaN    Own-child  White  Female           0.0           0.0
# 6                NaN    Unmarried  Black    Male           0.0           0.0
# 8      Other-service    Unmarried  White  Female           0.0           0.0
#
#    hours-per-week native-country  class  target  prediction
# 1            50.0  United-States  <=50K     9.0    7.059571
# 3            40.0  United-States   >50K    10.0   16.675821
# 4            30.0  United-States  <=50K    10.0    7.909593
# 6            40.0  United-States  <=50K     9.0    7.688815
# 8            40.0  United-States  <=50K    10.0   -1.385219

# %% [markdown]
# ## Missing values metrics

# %% [markdown]
# Look at missing values in a column

# %%
from evidently.report import Report
from evidently.metrics import ColumnMissingValuesMetric

report = Report(metrics=[ColumnMissingValuesMetric(column_name="workclass", values=["Private"], replace=False)])
report.run(current_data=current_data, reference_data=reference_data)
report
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_09e9b490923541a98c17f14604bf24ea = {"name": "Report", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "47f13b0b-caf6-4c50-a145-8d143193ef60", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Missing values in column 'workclass'"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "counter", "title": "", "size": 2, "id": "35cf0d8c-4534-43f2-b119-e71cf4df19c0", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "26423 (76.176%)", "label": "Current missed values"}, {"value": "10282 (72.639%)", "label": "Reference missed values"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "tabs", "title": "", "size": 2, "id": "7c9921db-9063-412d-ab41-10e5a807d4ba", "details": "", "alertsPosition": null, "alertStats": null, "params": null, "insights": [], "alerts": [], "tabs": [{"id": "1d407baa-fab0-4abe-bed6-2bc685e37e08", "title": "Current dataset", "widget": {"type": "table", "title": "All missed values table", "size": 2, "id": "3affc09c-daa5-4895-909f-2e69e11c95f5", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": ["Missed Value", "Count"], "data": [["Private", "24520 (70.689%)"], ["Pandas and Numpy null, NA, NaN, etc.", "1903 (5.486%)"], ["Empty string", "0 (0.0%)"], ["inf", "0 (0.0%)"], ["-inf", "0 (0.0%)"]]}, "insights": [], "additionalGraphs": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}}, {"id": "f5598346-e462-4057-8a4a-bd4b3ab4493b", "title": "Reference dataset", "widget": {"type": "table", "title": "All missed values table", "size": 2, "id": "ca313efe-e306-4c5a-8bba-197aad25819d", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": ["Missed Value", "Count"], "data": [["Private", "9386 (66.309%)"], ["Pandas and Numpy null, NA, NaN, etc.", "896 (6.33%)"], ["Empty string", "0 (0.0%)"], ["inf", "0 (0.0%)"], ["-inf", "0 (0.0%)"]]}, "insights": [], "additionalGraphs": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}}], "widgets": [], "pageSize": 5}]};
#     var additional_graphs_evidently_dashboard_09e9b490923541a98c17f14604bf24ea = {};
# </script>
# <script>
# function domReady(fn) {
#   // If we're early to the party
#   document.addEventListener("DOMContentLoaded", fn);
#   // If late; I mean on time.
#   if (document.readyState === "interactive" || document.readyState === "complete" ) {
#     fn();
#   }
# }
#
# domReady(function () {
#     requirejs(["evidently"], function(ev) {
#         drawDashboard(evidently_dashboard_09e9b490923541a98c17f14604bf24ea,
#         new Map(Object.entries(additional_graphs_evidently_dashboard_09e9b490923541a98c17f14604bf24ea)),
#         "root_evidently_dashboard_09e9b490923541a98c17f14604bf24ea");
#     },
#     function(err) {
#         $("#root_evidently_dashboard_09e9b490923541a98c17f14604bf24ea").innerHTML = "Failed to load";
#     })
# });
# </script>
# <div class="reset-this-parent" id="root_evidently_dashboard_09e9b490923541a98c17f14604bf24ea">Loading...</div>

# %%
report = Report(metrics=[ColumnMissingValuesMetric(column_name="workclass")])
report.run(current_data=current_data, reference_data=None)
report
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_6141be653868490680b335a4b57c5870 = {"name": "Report", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "5a05595c-67bd-4788-a084-9d894927a284", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Missing values in column 'workclass'"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "counter", "title": "", "size": 2, "id": "229266c6-5e27-4e43-96f9-3219aa82b6d3", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "1903 (5.486%)", "label": "Current missed values"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "table", "title": "All missed values table", "size": 2, "id": "99baeeed-4ed1-4a0c-8110-9c48819a5b88", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": ["Missed Value", "Count"], "data": [["Pandas and Numpy null, NA, NaN, etc.", "1903 (5.486%)"], ["Empty string", "0 (0.0%)"], ["-inf", "0 (0.0%)"], ["inf", "0 (0.0%)"]]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}]};
#     var additional_graphs_evidently_dashboard_6141be653868490680b335a4b57c5870 = {};
# </script>
# <script>
# function domReady(fn) {
#   // If we're early to the party
#   document.addEventListener("DOMContentLoaded", fn);
#   // If late; I mean on time.
#   if (document.readyState === "interactive" || document.readyState === "complete" ) {
#     fn();
#   }
# }
#
# domReady(function () {
#     requirejs(["evidently"], function(ev) {
#         drawDashboard(evidently_dashboard_6141be653868490680b335a4b57c5870,
#         new Map(Object.entries(additional_graphs_evidently_dashboard_6141be653868490680b335a4b57c5870)),
#         "root_evidently_dashboard_6141be653868490680b335a4b57c5870");
#     },
#     function(err) {
#         $("#root_evidently_dashboard_6141be653868490680b335a4b57c5870").innerHTML = "Failed to load";
#     })
# });
# </script>
# <div class="reset-this-parent" id="root_evidently_dashboard_6141be653868490680b335a4b57c5870">Loading...</div>

# %% [markdown]
# Look at missing values in overall dataset

# %%
from evidently.report import Report
from evidently.metrics import DatasetMissingValuesMetric

report = Report(metrics=[DatasetMissingValuesMetric()])
report.run(current_data=current_data, reference_data=None)
report
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_3c5a279591474dcbbc4ccd2830cbadab = {"name": "Report", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "8e18ec53-9d18-4b97-8942-9a916c735f1a", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Dataset Missing Values"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "counter", "title": "", "size": 2, "id": "42955102-52d6-4d41-a072-342a9f4db450", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "4373 (0.742%)", "label": "Current dataset missed values"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "tabs", "title": "Current dataset missing values statistic", "size": 2, "id": "fe1d36ff-edbf-404f-beb9-0a6e48f24d7e", "details": "", "alertsPosition": null, "alertStats": null, "params": null, "insights": [], "alerts": [], "tabs": [{"id": "0ec7bf6c-4938-4d6b-bb51-d868a8ce9f24", "title": "Table", "widget": {"type": "table", "title": "", "size": 2, "id": "2bb60ba9-311f-4470-8604-677f01107f13", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": ["Value", "Count"], "data": [["age", "0"], ["workclass", "1903"], ["fnlwgt", "0"], ["education", "0"], ["education-num", "0"], ["marital-status", "0"], ["occupation", "1907"], ["relationship", "0"], ["race", "0"], ["sex", "0"], ["capital-gain", "0"], ["capital-loss", "0"], ["hours-per-week", "0"], ["native-country", "563"], ["class", "0"], ["target", "0"], ["prediction", "0"]]}, "insights": [], "additionalGraphs": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}}, {"id": "351a0660-eea0-41d6-8744-626152eba841", "title": "Histogram", "widget": {"type": "big_graph", "title": "", "size": 2, "id": "8a3924b0-fb8f-4aa5-a343-76bcc1476090", "details": "", "alertsPosition": null, "alertStats": null, "params": {"data": [{"marker": {"color": "#ed0400"}, "name": "", "orientation": "v", "x": ["age", "workclass", "fnlwgt", "education", "education-num", "marital-status", "occupation", "relationship", "race", "sex", "capital-gain", "capital-loss", "hours-per-week", "native-country", "class", "target", "prediction"], "y": [0, 1903, 0, 0, 0, 0, 1907, 0, 0, 0, 0, 0, 0, 563, 0, 0, 0], "type": "bar"}], "layout": {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}, "pattern": {"fillmode": "overlay", "size": 10, "solidity": 0.2}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}, "pattern": {"fillmode": "overlay", "size": 10, "solidity": 0.2}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{" ...
