# %% [markdown]
# # Test Generators
# If you want to create a list of tests, you can do it with a list comprehension.
# As an example we create tests for quantiles.
#
# But before that we prepare reference and current test data:

# %%
import numpy as np
from sklearn.datasets import fetch_openml


data = fetch_openml(name='adult', version=2, as_frame='auto')
data.frame['target'] = data.frame['education-num']
data.frame['preds'] = data.frame['education-num'].values + np.random.normal(0, 6, data.frame.shape[0])
reference_data = data.frame[:20000]
current_data = data.frame[20000:]

# %% [markdown]
# Now we can import the quantiles test and test suite classes from **evidently** and add a list of test with different quantiles to our suite:

# %%
from evidently.tests import TestValueQuantile
from evidently.test_suite import TestSuite


suite = TestSuite(tests=[
    TestValueQuantile(column_name="education-num", quantile=quantile) for quantile in [0.5, 0.9, 0.99]
])

suite.run(current_data=current_data, reference_data=reference_data)
suite
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_bab4bc8043474df28fd0ace715064c6c = {"name": "Test Suite", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "8c59803d-679a-44e5-ba5c-b6898fa1bc83", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "3", "label": "Tests"}, {"value": "3", "label": "Success"}, {"value": "0", "label": "Warning"}, {"value": "0", "label": "Fail"}, {"value": "0", "label": "Error"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "test_suite", "title": "", "size": 2, "id": "624b88d1-74c2-4ed2-af2e-29e65db6ff07", "details": "", "alertsPosition": null, "alertStats": null, "params": {"tests": [{"title": "Quantile Value", "description": "The 0.5 quantile value of the column **education-num** is 10. The test threshold is eq=10 \u00b1 1.", "state": "success", "details": {"parts": [{"id": "35388b55-4865-44f2-a696-7fc1d0f19245", "title": "", "type": "widget"}]}, "groups": {"by_feature": "education-num", "test_group": "data_quality", "test_type": "Quantile Value"}}, {"title": "Quantile Value", "description": "The 0.9 quantile value of the column **education-num** is 13. The test threshold is eq=13 \u00b1 1.3.", "state": "success", "details": {"parts": [{"id": "f35c5878-29a6-4861-9f89-81d02be95260", "title": "", "type": "widget"}]}, "groups": {"by_feature": "education-num", "test_group": "data_quality", "test_type": "Quantile Value"}}, {"title": "Quantile Value", "description": "The 0.99 quantile value of the column **education-num** is 16. The test threshold is eq=16 \u00b1 1.6.", "state": "success", "details": {"parts": [{"id": "377b3a9c-3db2-4bd6-8bbb-809a81081c27", "title": "", "type": "widget"}]}, "groups": {"by_feature": "education-num", "test_group": "data_quality", "test_type": "Quantile Value"}}], "testGroupTypes": [{"id": "by_feature", "title": "By feature", "values": [{"id": "no group", "title": "Dataset-level tests", "description": "Some tests cannot be grouped by feature", "sort_index": 0, "severity": null}]}, {"id": "test_group", "title": "By test group", "values": [{"id": "no group", "title": "Ungrouped", "description": "Some tests don\u2019t belong to any group under the selected condition", "sort_index": 0, "severity": null}, {"id": "classification", "title": "Classification", "description": "", "sort_index": 0, "severity": null}, {"id": "data_drift", "title": "Data Drift", "description": "", "sort_index": 0, "severity": null}, {"id": "data_integrity", "title": "Data Integrity", "description": "", "sort_index": 0, "severity": null}, {"id": "data_quality", "title": "Data Quality", "description": "", "sort_index": 0, "severity": null}, {"id": "regression", "title": "Regression", "description": "", "sort_index": 0, "severity": null}]}, {"id": "test_type", "title": "By test type", "values": []}, {"id": "by_class", "title": "By class", "values": []}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}]};
#     var additional_graphs_evidently_dashboard_bab4bc8043474df28fd0ace715064c6c = {"35388b55-4865-44f2-a696-7fc1d0f19245": {"type": "big_graph", "title": "", "size": 2, "id": "ec339204-37d2-4b36-938d-cd061b781153", "details": "", "alertsPosition": null, "alertStats": null, "params": {"data": [{"marker": {"color": "#ed0400"}, "name": "current", "orientation": "v", "x": [1.0, 1.6818181818181817, 2.3636363636363633, 3.0454545454545454, 3.727272727272727, 4.409090909090908, 5.090909090909091, 5.7727272727272725, 6.454545454545454, 7.136363636363636, 7.8181818181818175, 8.5, 9.181818181818182, 9.863636363636363, 10.545454545454545, 11.227272727272727, 11.909090909090908, 12.59090909090909, 13.272727272727272, 13.954545454545453, 14.636363636363635, 15.318181818181817], "y": [45, 151, 296, 0, 573, 458, 0, 825, 1020, 0, 395, 9302, 0, 6477, 1226, 0, 955, 4717, 0, 1524, 509, 369], "type": "bar"}, {"marker": {"color": "#4d4d4d"}, "name": "reference", "orientation": "v", "x": [1.0, 1.6818181818181817, 2.3636363636363633, 3.0454545454545454, 3.727272727272727, 4.409090909090908, 5.090909090909091, 5.7727272727272725, 6.454545454545454, 7.136363636363636, 7.8181818181818175, 8.5, 9.181818181818182, 9.863636363636363, 10.545454545454545, 11.227272727272727, 11.909090909090908, 12.59090909090909, 13.272727272727272, 13.954545454545453, 14.636363636363635, 15.318181818181817], "y": [38, 96, 213, 0, 382, 298, 0, 564, 792, 0, 262, 6482, 0, 4401, 835, 0, 646, 3308, 0, 1133, 325, 225], "type": "bar"}, {"line": {"color": "#4d4d4d", "dash": "dash", "width": 3}, "mode": "lines", "name": "approx", "x": [10.0, 10.0], "y": [0, 9302], "type": "scatter"}, {"line": {"color": "green", "width": 3}, "mode": "lines", "name": "current education-num 0.5 quantile", "x": [10.0, 10.0], "y": [0, 9302], "type": "scatter"}], "layout": {"shapes": [{"fillcolor": "green", "line": {"width": 0}, "opacity": 0.25, "type": "rect", "x0": NaN, "x1": NaN, "xref": "x", "y0": 0, "y1": 1, "yref": "y domain"}, {"fillcolor": "green", "line": {"width": 0}, "opacity": 0.25, "type": "rect", "x0": 9.0, "x1": 11.0, "xref": "x", "y0": 0, "y1": 1, "yref": "y domain"}, {"fillcolor": "green", "line": {"width": 0}, "opacity": 0.25, "type": "rect", "x0": 9.0, "x1": 11.0, "xref": "x", "y0": 0, "y1": 1, "yref": "y domain"}], "showlegend": true, "template": {"data": {"barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}, "pattern": {"fillmode": "overlay", "size": 10, "solidity": 0.2}}, "type": "barpolar"}], "bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}, "pattern": {"fillmode": "overlay", "size": 10, "solidity": 0.2}}, "type": "bar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "heatmap": ...

# %% [markdown]
# Or you can do it for a list with specific columns

# %%
from evidently.tests import TestFeatureValueMin


# test that values in specified columns are positive (greater than zero condition)
suite = TestSuite(tests=[
    TestFeatureValueMin(column_name=column_name, gt=0) for column_name in ["age", "fnlwgt", "education-num"]
])

suite.run(current_data=current_data, reference_data=reference_data)
suite
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_21114c0211a54b209c7c172baf7038b7 = {"name": "Test Suite", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "82d6dd95-de6c-4145-bcef-505aa33ed1b2", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "3", "label": "Tests"}, {"value": "3", "label": "Success"}, {"value": "0", "label": "Warning"}, {"value": "0", "label": "Fail"}, {"value": "0", "label": "Error"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "test_suite", "title": "", "size": 2, "id": "e8f2003a-fd59-49f6-9c33-f5f9fddaa83f", "details": "", "alertsPosition": null, "alertStats": null, "params": {"tests": [{"title": "Min Value", "description": "The minimum value of the column **age** is 17.0 The test threshold is gt=0.", "state": "success", "details": {"parts": [{"id": "8326b106-e5f1-4c48-a7f1-0a7343886a67", "title": "Min Value age", "type": "widget"}]}, "groups": {"by_feature": "age", "test_group": "data_quality", "test_type": "Min Value"}}, {"title": "Min Value", "description": "The minimum value of the column **fnlwgt** is 12285.0 The test threshold is gt=0.", "state": "success", "details": {"parts": [{"id": "99d9a535-e647-45cd-b070-fa0a1018de79", "title": "Min Value fnlwgt", "type": "widget"}]}, "groups": {"by_feature": "fnlwgt", "test_group": "data_quality", "test_type": "Min Value"}}, {"title": "Min Value", "description": "The minimum value of the column **education-num** is 1.0 The test threshold is gt=0.", "state": "success", "details": {"parts": [{"id": "20dc4a1e-6af8-410b-a9be-7397df10afd7", "title": "Min Value education-num", "type": "widget"}]}, "groups": {"by_feature": "education-num", "test_group": "data_quality", "test_type": "Min Value"}}], "testGroupTypes": [{"id": "by_feature", "title": "By feature", "values": [{"id": "no group", "title": "Dataset-level tests", "description": "Some tests cannot be grouped by feature", "sort_index": 0, "severity": null}]}, {"id": "test_group", "title": "By test group", "values": [{"id": "no group", "title": "Ungrouped", "description": "Some tests don\u2019t belong to any group under the selected condition", "sort_index": 0, "severity": null}, {"id": "classification", "title": "Classification", "description": "", "sort_index": 0, "severity": null}, {"id": "data_drift", "title": "Data Drift", "description": "", "sort_index": 0, "severity": null}, {"id": "data_integrity", "title": "Data Integrity", "description": "", "sort_index": 0, "severity": null}, {"id": "data_quality", "title": "Data Quality", "description": "", "sort_index": 0, "severity": null}, {"id": "regression", "title": "Regression", "description": "", "sort_index": 0, "severity": null}]}, {"id": "test_type", "title": "By test type", "values": []}, {"id": "by_class", "title": "By class", "values": []}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}]};
#     var additional_graphs_evidently_dashboard_21114c0211a54b209c7c172baf7038b7 = {"8326b106-e5f1-4c48-a7f1-0a7343886a67": {"type": "big_graph", "title": "", "size": 2, "id": "c65c4447-5bea-43a7-a34b-be66f4f66bc1", "details": "", "alertsPosition": null, "alertStats": null, "params": {"data": [{"marker": {"color": "#ed0400"}, "name": "current", "orientation": "v", "x": [17.0, 20.17391304347826, 23.347826086956523, 26.52173913043478, 29.695652173913043, 32.869565217391305, 36.04347826086956, 39.21739130434783, 42.391304347826086, 45.565217391304344, 48.73913043478261, 51.91304347826087, 55.086956521739125, 58.26086956521739, 61.43478260869565, 64.6086956521739, 67.78260869565217, 70.95652173913044, 74.13043478260869, 77.30434782608695, 80.47826086956522, 83.65217391304347, 86.82608695652173], "y": [2138, 2110, 2151, 2251, 2262, 3151, 2223, 2091, 1950, 1748, 1570, 1573, 968, 850, 620, 428, 287, 220, 101, 61, 34, 14, 41], "type": "bar"}, {"marker": {"color": "#4d4d4d"}, "name": "reference", "orientation": "v", "x": [17.0, 20.17391304347826, 23.347826086956523, 26.52173913043478, 29.695652173913043, 32.869565217391305, 36.04347826086956, 39.21739130434783, 42.391304347826086, 45.565217391304344, 48.73913043478261, 51.91304347826087, 55.086956521739125, 58.26086956521739, 61.43478260869565, 64.6086956521739, 67.78260869565217, 70.95652173913044, 74.13043478260869, 77.30434782608695, 80.47826086956522, 83.65217391304347, 86.82608695652173], "y": [1485, 1493, 1403, 1484, 1594, 2172, 1527, 1496, 1317, 1275, 1020, 1110, 702, 572, 449, 331, 173, 203, 94, 41, 29, 5, 25], "type": "bar"}, {"line": {"color": "#4d4d4d", "dash": "dash", "width": 3}, "mode": "lines", "name": "gt", "x": [0.0, 0.0], "y": [0, 3151], "type": "scatter"}, {"line": {"color": "green", "width": 3}, "mode": "lines", "name": "current age min value", "x": [17.0, 17.0], "y": [0, 3151], "type": "scatter"}], "layout": {"showlegend": true, "template": {"data": {"barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}, "pattern": {"fillmode": "overlay", "size": 10, "solidity": 0.2}}, "type": "barpolar"}], "bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}, "pattern": {"fillmode": "overlay", "size": 10, "solidity": 0.2}}, "type": "bar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "histogr ...

# %% [markdown]
# But if you want to use column names in tests generation, sometimes you can get them before the suite calculation is already launched.
#
# In this case you can use test generators:

# %%
from evidently.tests.base_test import generate_column_tests

from evidently.tests import TestColumnShareOfNulls

suite = TestSuite(tests=[generate_column_tests(TestColumnShareOfNulls)])
suite.run(current_data=current_data, reference_data=reference_data)
suite.show()
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_35317eba35dc47beafd4e7bf345b508f = {"name": "Test Suite", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "153954a4-0684-467f-beda-757f03cc4d9c", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "17", "label": "Tests"}, {"value": "17", "label": "Success"}, {"value": "0", "label": "Warning"}, {"value": "0", "label": "Fail"}, {"value": "0", "label": "Error"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "test_suite", "title": "", "size": 2, "id": "5e1022ea-0fa0-4533-9dbc-886c913a4a22", "details": "", "alertsPosition": null, "alertStats": null, "params": {"tests": [{"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **class** is 0. The test threshold is lte=0 \u00b1 1e-12.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **education** is 0. The test threshold is lte=0 \u00b1 1e-12.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **marital-status** is 0. The test threshold is lte=0 \u00b1 1e-12.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **native-country** is 0.0176. The test threshold is lte=0.0174 \u00b1 0.00174.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **occupation** is 0.0558. The test threshold is lte=0.06 \u00b1 0.006.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **race** is 0. The test threshold is lte=0 \u00b1 1e-12.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **relationship** is 0. The test threshold is lte=0 \u00b1 1e-12.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **sex** is 0. The test threshold is lte=0 \u00b1 1e-12.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **workclass** is 0.0555. The test threshold is lte=0.0599 \u00b1 0.00599.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **age** is 0. The test threshold is lte=0 \u00b1 1e-12.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **capital-gain** is 0. The te ...
#     var additional_graphs_evidently_dashboard_35317eba35dc47beafd4e7bf345b508f = {};
# </script>
# <script>
# function domReady(fn) {
#   // If we're early to the party
#   document.addEventListener("DOMContentLoaded", fn);
#   // If late; I mean on time.
#   if (document.readyState === "interactive" || document.readyState === "complete" ) {
#     fn();
#   }
# }
#
# domReady(function () {
#     requirejs(["evidently"], function(ev) {
#         drawDashboard(evidently_dashboard_35317eba35dc47beafd4e7bf345b508f,
#         new Map(Object.entries(addition

# %% [markdown]
# By default, it generates tests with no parameters for all columns.
# If you want to set custom parameters for all generated tests, you can do it with a separate parameter

# %%
# set condition for all generated tests and specify that we want to generate tests for all columns explicitly
suite = TestSuite(tests=[generate_column_tests(TestColumnShareOfNulls, columns="all", parameters={"lt": 0.5})])
suite.run(current_data=current_data, reference_data=reference_data)
suite.show()
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_9d0a214fc20c4b749e1869f8c8509bcc = {"name": "Test Suite", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "57e33aee-53fa-4299-9891-9e83263dbea5", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "17", "label": "Tests"}, {"value": "17", "label": "Success"}, {"value": "0", "label": "Warning"}, {"value": "0", "label": "Fail"}, {"value": "0", "label": "Error"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "test_suite", "title": "", "size": 2, "id": "4f1d8d7d-2a0d-4ea9-9cb3-bb25a6944e22", "details": "", "alertsPosition": null, "alertStats": null, "params": {"tests": [{"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **class** is 0. The test threshold is lt=0.5.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **education** is 0. The test threshold is lt=0.5.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **marital-status** is 0. The test threshold is lt=0.5.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **native-country** is 0.0176. The test threshold is lt=0.5.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **occupation** is 0.0558. The test threshold is lt=0.5.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **race** is 0. The test threshold is lt=0.5.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **relationship** is 0. The test threshold is lt=0.5.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **sex** is 0. The test threshold is lt=0.5.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **workclass** is 0.0555. The test threshold is lt=0.5.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **age** is 0. The test threshold is lt=0.5.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **capital-gain** is 0. The test threshold is lt=0.5.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Shar ...
#     var additional_graphs_evidently_dashboard_9d0a214fc20c4b749e1869f8c8509bcc = {};
# </script>
# <script>
# function domReady(fn) {
#   // If we're early to the party
#   document.addEventListener("DOMContentLoaded", fn);
#   // If late; I mean on time.
#   if (document.readyState === "interactive" || document.readyState === "complete" ) {
#     fn();
#   }
# }
#
# domReady(function () {
#     requirejs(["evidently"], function(ev) {
#         drawDashboard(evidently_dashboard_9d0a214fc20c4b749e1869f8c8509bcc,
#         new Map(Object.entries(additional_graphs_evidently_dashboard_9d0a214fc20c4b749e1869f8c8509bcc)),
#         "root_evidently_dashboard_9d0a214fc20c4b749e1869f8c8509bcc");
#     },
#     function(err) {
#         $("#root_evidently_dashboard_9d0a214fc20c4b749e186

# %% [markdown]
# If you want to generate tests for numeric features only, you can set parameter `columns` to "num"

# %%
suite = TestSuite(tests=[generate_column_tests(TestFeatureValueMin, columns="num")])
suite.run(current_data=current_data, reference_data=reference_data)
suite.show()
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_bf13fb57a9e24a88988b504466545da1 = {"name": "Test Suite", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "35c7788f-524c-435b-b56c-d2458158e294", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "7", "label": "Tests"}, {"value": "5", "label": "Success"}, {"value": "0", "label": "Warning"}, {"value": "2", "label": "Fail"}, {"value": "0", "label": "Error"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "test_suite", "title": "", "size": 2, "id": "fb663d27-ae3f-41d9-9696-bc962b3edd7f", "details": "", "alertsPosition": null, "alertStats": null, "params": {"tests": [{"title": "Min Value", "description": "The minimum value of the column **age** is 17.0 The test threshold is gte=17.", "state": "success", "details": {"parts": [{"id": "66d21366-eee6-4743-92ee-eccd4a57eab3", "title": "Min Value age", "type": "widget"}]}, "groups": {"by_feature": "age", "test_group": "data_quality", "test_type": "Min Value"}}, {"title": "Min Value", "description": "The minimum value of the column **capital-gain** is 0.0 The test threshold is gte=0.", "state": "success", "details": {"parts": [{"id": "bd4a8c94-869c-4ace-814e-8da7c282a85c", "title": "Min Value capital-gain", "type": "widget"}]}, "groups": {"by_feature": "capital-gain", "test_group": "data_quality", "test_type": "Min Value"}}, {"title": "Min Value", "description": "The minimum value of the column **capital-loss** is 0.0 The test threshold is gte=0.", "state": "success", "details": {"parts": [{"id": "0be2f8da-de3b-4eac-9883-a619d7a5d18b", "title": "Min Value capital-loss", "type": "widget"}]}, "groups": {"by_feature": "capital-loss", "test_group": "data_quality", "test_type": "Min Value"}}, {"title": "Min Value", "description": "The minimum value of the column **education-num** is 1.0 The test threshold is gte=1.", "state": "success", "details": {"parts": [{"id": "52681859-d5b8-4f73-8de0-cc675b28a835", "title": "Min Value education-num", "type": "widget"}]}, "groups": {"by_feature": "education-num", "test_group": "data_quality", "test_type": "Min Value"}}, {"title": "Min Value", "description": "The minimum value of the column **fnlwgt** is 12285.0 The test threshold is gte=1.35e+04.", "state": "fail", "details": {"parts": [{"id": "0833f21f-1ef2-4821-afe2-a34a0d3ed0f7", "title": "Min Value fnlwgt", "type": "widget"}]}, "groups": {"by_feature": "fnlwgt", "test_group": "data_quality", "test_type": "Min Value"}}, {"title": "Min Value", "description": "The minimum value of the column **hours-per-week** is 1.0 The test threshold is gte=1.", "state": "success", "details": {"parts": [{"id": "babe2f2a-6e98-423d-8afc-f5a34c8baa83", "title": "Min Value hours-per-week", "type": "widget"}]}, "groups": {"by_feature": "hours-per-week", "test_group": "data_quality", "test_type": "Min Value"}}, {"title": "Min Value", "description": "The minimum value of the column **preds** is -16.43 The test threshold is gte=-16.3.", "state": "fail", "details": {"parts": [{"id": "1f79bb32-43d7-4a75-9c0b-a67151282ad1", "title": "Min Value preds", "type": "widget"}]}, "groups": {"by_feature": "preds", "test_group": "data_quality", "test_type": "Min Value"}}], "testGroupTypes": [{"id": "by_feature", "title": "By feature", "values": [{"id": "no group", "title": "Dataset-level tests", "description": "Some tests cannot be grouped by feature", "sort_index": 0, "severity": null}]}, {"id": "test_group", "title": "By test group", "values": [{"id": "no group", "title": "Ungrouped", "description": "Some tests don\u2019t belong to any group under the selected condition", "sort_index": 0, "severity": null}, {"id": "classification", "title": "Classification", "description": "", "sort_index": 0, "severity": null}, {"id": "data_drift", "title": "Data Drift", "description": "", "sort_index": 0, "severity": null}, {"id": "data_integrity", "title": "Data Integrity", "description": "", "sort_index": 0, "severity": null}, {" ...
#     var additional_graphs_evidently_dashboard_bf13fb57a9e24a88988b504466545da1 = {"66d21366-eee6-4743-92ee-eccd4a57eab3": {"type": "big_graph", "title": "", "size": 2, "id": "8c9dcc37-f0c4-467a-b356-2acff43a5e81", "details": "", "alertsPosition": null, "alertStats": null, "params": {"data": [{"marker": {"color": "#ed0400"}, "name": "current", "orientation": "v", "x": [17.0, 20.17391304347826, 23.347826086956523, 26.52173913043478, 29.695652173913043, 32.869565217391305, 36.04347826086956, 39.21739130434783, 42.391304347826086, 45.565217391304344, 48.73913043478261, 51.91304347826087, 55.086956521739125, 58.26086956521739, 61.43478260869565, 64.6086956521739, 67.78260869565217, 70.95652173913044, 74.13043478260869, 77.30434782608695, 80.47826086956522, 83.65217391304347, 86.82608695652173], "y": [2138, 2110, 2151, 2251, 2262, 3151, 2223, 2091, 1950, 1748, 1570, 1573, 968, 850, 620, 428, 287, 220, 101, 61, 34, 14, 41], "type": "bar"}, {"marker": {"color": "#4d4d4d"}, "name": "reference", "orientation": "v", "x": [17.0, 20.17391304347826, 23.347826086956523, 26.52173913043478, 29.695652173913043, 32.869565217391305, 36.04347826086956, 39.21739130434783, 42.391304347826086, 45.565217391304344, 48.73913043478261, 51.91304347826087, 55.086956521739125, 58.26086956521739, 61.43478260869565, 64.6086956521739, 67.78260869565217, 70.95652173913044, 74.13043478260869, 77.30434782608695, 80.47826086956522, 83.65217391304347, 86.82608695652173], "y": [1485, 1493, 1403, 1484, 1594, 2172, 1527, 1496, 1317, 1275, 1020, 1110, 702, 572, 449, 331, 173, 203, 94, 41, 29, 5, 25], "type": "bar"}, {"line": {"color": "#4d4d4d", "dash": "dash", "width": 3}, "mode": "lines", "name": "gte", "x": [17.0, 17.0], "y": [0, 3151], "type": "scatter"}, {"line": {"color": "green", "width": 3}, "mode": "lines", "name": "current age min value", "x": [17.0, 17.0], "y": [0, 3151], "type": "scatter"}], "layout": {"shapes": [{"fillcolor": "green", "line": {"width": 0}, "opacity": 0.25, "type": "rect", "x0": 17.0, "x1": NaN, "xref": "x", "y0": 0, "y1": 1, "yref": "y domain"}], "showlegend": true, "template": {"data": {"barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}, "pattern": {"fillmode": "overlay", "size": 10, "solidity": 0.2}}, "type": "barpolar"}], "bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}, "pattern": {"fillmode": "overlay", "size": 10, "solidity": 0.2}}, "type": "bar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "

# %% [markdown]
# If you want to generate tests for category features only, you can set parameter `columns` to "cat"

# %%
suite = TestSuite(tests=[generate_column_tests(TestColumnShareOfNulls, columns="cat", parameters={"lt": 0.1})])
suite.run(current_data=current_data, reference_data=reference_data)
suite.show()
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_dca41f337b384ad5a25f1076a271cf8c = {"name": "Test Suite", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "b113c2e9-3ecf-43e7-b2b5-1131a2c779d6", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "9", "label": "Tests"}, {"value": "9", "label": "Success"}, {"value": "0", "label": "Warning"}, {"value": "0", "label": "Fail"}, {"value": "0", "label": "Error"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "test_suite", "title": "", "size": 2, "id": "22bd183f-d7b3-4e08-9f7a-c9dca221611c", "details": "", "alertsPosition": null, "alertStats": null, "params": {"tests": [{"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **class** is 0. The test threshold is lt=0.1.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **education** is 0. The test threshold is lt=0.1.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **marital-status** is 0. The test threshold is lt=0.1.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **native-country** is 0.0176. The test threshold is lt=0.1.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **occupation** is 0.0558. The test threshold is lt=0.1.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **race** is 0. The test threshold is lt=0.1.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **relationship** is 0. The test threshold is lt=0.1.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **sex** is 0. The test threshold is lt=0.1.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}, {"title": "The Share of Nulls in a Column", "description": "The share of nulls and missing values in the column **workclass** is 0.0555. The test threshold is lt=0.1.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Nulls in a Column"}}], "testGroupTypes": [{"id": "by_feature", "title": "By feature", "values": [{"id": "no group", "title": "Dataset-level tests", "description": "Some tests cannot be grouped by feature", "sort_index": 0, "severity": null}]}, {"id": "test_group", "title": "By test group", "values": [{"id": "no group", "title": "Ungrouped", "description": "Some tests don\u2019t belong to any group under the selected condition", "sort_index": 0, "severity": null}, {"id": "classification", "title": "Classification", "description": "", "sort_index": 0, "severity": null}, {"id": "data_drift", "t ...
#     var additional_graphs_evidently_dashboard_dca41f337b384ad5a25f1076a271cf8c = {};
# </script>
# <script>
# function domReady(fn) {
#   // If we're early to the party
#   document.addEventListener("DOMContentLoaded", fn);
#   // If late; I mean on time.
#   if (document.readyState === "interactive" || document.readyState === "complete" ) {
#     fn();
#   }
# }
#
# domReady(function () {
#     requirejs(["evidently"], function(ev) {
#         drawDashboard(evidently_dashboard_dca41f337b384ad5a25f1076a271cf8c,
#         new Map(Object.entries(additional_graphs_evidently_dashboard_dca41f337b384ad5a25f1076a271cf8c)),
#         "root_evidently_dashboard_dca41f337b384ad5a25f1076a271cf8c");
#     },
#     function(err) {
#         $("#root_evidently_dashboard_dca41f337b384ad5a25f1076a271cf8c").innerHTML = "Failed to load";
#     })
# });
# </script>
# <div class="reset-this-parent" id="root_evidently_dashboard_dca41f337b384ad5a25f1076a271cf8c">Loading...</div>

# %% [markdown]
# Also you can call the generator with columns list:

# %%
suite = TestSuite(tests=[generate_column_tests(TestFeatureValueMin, columns=["age", "fnlwgt", "education-num"], parameters={"gt": 0})])
suite.run(current_data=current_data, reference_data=reference_data)
suite.show()
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_7558cce6f8194dac86a67dbe3befaf31 = {"name": "Test Suite", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "f290c594-734a-457c-905c-7ff5ccb9a3c5", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "3", "label": "Tests"}, {"value": "3", "label": "Success"}, {"value": "0", "label": "Warning"}, {"value": "0", "label": "Fail"}, {"value": "0", "label": "Error"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "test_suite", "title": "", "size": 2, "id": "cfffbdd7-009d-4c81-b890-0a7d9de701ee", "details": "", "alertsPosition": null, "alertStats": null, "params": {"tests": [{"title": "Min Value", "description": "The minimum value of the column **age** is 17.0 The test threshold is gt=0.", "state": "success", "details": {"parts": [{"id": "6b60bdd8-4016-4c61-8583-a5fd47bbcc05", "title": "Min Value age", "type": "widget"}]}, "groups": {"by_feature": "age", "test_group": "data_quality", "test_type": "Min Value"}}, {"title": "Min Value", "description": "The minimum value of the column **fnlwgt** is 12285.0 The test threshold is gt=0.", "state": "success", "details": {"parts": [{"id": "c57fd1ee-829f-46c5-842d-af517fd8d762", "title": "Min Value fnlwgt", "type": "widget"}]}, "groups": {"by_feature": "fnlwgt", "test_group": "data_quality", "test_type": "Min Value"}}, {"title": "Min Value", "description": "The minimum value of the column **education-num** is 1.0 The test threshold is gt=0.", "state": "success", "details": {"parts": [{"id": "a28a8bf1-752b-4d28-98ee-f543b3bf7f7a", "title": "Min Value education-num", "type": "widget"}]}, "groups": {"by_feature": "education-num", "test_group": "data_quality", "test_type": "Min Value"}}], "testGroupTypes": [{"id": "by_feature", "title": "By feature", "values": [{"id": "no group", "title": "Dataset-level tests", "description": "Some tests cannot be grouped by feature", "sort_index": 0, "severity": null}]}, {"id": "test_group", "title": "By test group", "values": [{"id": "no group", "title": "Ungrouped", "description": "Some tests don\u2019t belong to any group under the selected condition", "sort_index": 0, "severity": null}, {"id": "classification", "title": "Classification", "description": "", "sort_index": 0, "severity": null}, {"id": "data_drift", "title": "Data Drift", "description": "", "sort_index": 0, "severity": null}, {"id": "data_integrity", "title": "Data Integrity", "description": "", "sort_index": 0, "severity": null}, {"id": "data_quality", "title": "Data Quality", "description": "", "sort_index": 0, "severity": null}, {"id": "regression", "title": "Regression", "description": "", "sort_index": 0, "severity": null}]}, {"id": "test_type", "title": "By test type", "values": []}, {"id": "by_class", "title": "By class", "values": []}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}]};
#     var additional_graphs_evidently_dashboard_7558cce6f8194dac86a67dbe3befaf31 = {"6b60bdd8-4016-4c61-8583-a5fd47bbcc05": {"type": "big_graph", "title": "", "size": 2, "id": "71e30062-e648-4d5e-8ed2-c4577e0c09b3", "details": "", "alertsPosition": null, "alertStats": null, "params": {"data": [{"marker": {"color": "#ed0400"}, "name": "current", "orientation": "v", "x": [17.0, 20.17391304347826, 23.347826086956523, 26.52173913043478, 29.695652173913043, 32.869565217391305, 36.04347826086956, 39.21739130434783, 42.391304347826086, 45.565217391304344, 48.73913043478261, 51.91304347826087, 55.086956521739125, 58.26086956521739, 61.43478260869565, 64.6086956521739, 67.78260869565217, 70.95652173913044, 74.13043478260869, 77.30434782608695, 80.47826086956522, 83.65217391304347, 86.82608695652173], "y": [2138, 2110, 2151, 2251, 2262, 3151, 2223, 2091, 1950, 1748, 1570, 1573, 968, 850, 620, 428, 287, 220, 101, 61, 34, 14, 41], "type": "bar"}, {"marker": {"color": "#4d4d4d"}, "name": "reference", "orientation": "v", "x": [17.0, 20.17391304347826, 23.347826086956523, 26.52173913043478, 29.695652173913043, 32.869565217391305, 36.04347826086956, 39.21739130434783, 42.391304347826086, 45.565217391304344, 48.73913043478261, 51.91304347826087, 55.086956521739125, 58.26086956521739, 61.43478260869565, 64.6086956521739, 67.78260869565217, 70.95652173913044, 74.13043478260869, 77.30434782608695, 80.47826086956522, 83.65217391304347, 86.82608695652173], "y": [1485, 1493, 1403, 1484, 1594, 2172, 1527, 1496, 1317, 1275, 1020, 1110, 702, 572, 449, 331, 173, 203, 94, 41, 29, 5, 25], "type": "bar"}, {"line": {"color": "#4d4d4d", "dash": "dash", "width": 3}, "mode": "lines", "name": "gt", "x": [0.0, 0.0], "y": [0, 3151], "type": "scatter"}, {"line": {"color": "green", "width": 3}, "mode": "lines", "name": "current age min value", "x": [17.0, 17.0], "y": [0, 3151], "type": "scatter"}], "layout": {"showlegend": true, "template": {"data": {"barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}, "pattern": {"fillmode": "overlay", "size": 10, "solidity": 0.2}}, "type": "barpolar"}], "bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}, "pattern": {"fillmode": "overlay", "size": 10, "solidity": 0.2}}, "type": "bar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "histogr ...

# %% [markdown]
# # Metrics generator
# Metrics generator works like test's - you can use a list comprehension or support function

# %%
from evidently.metrics import DataQualityValueRangeMetric
from evidently.metrics.base_metric import generate_column_metrics
from evidently.report import Report

report = Report(
    metrics=[
        generate_column_metrics(
            DataQualityValueRangeMetric,
            columns="num",
            parameters={"left": 0, "right": 10}
        )
    ]
)
report.run(current_data=current_data, reference_data=reference_data)
report.show()
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_4f31a981731b4755b5082a66a574bfc6 = {"name": "Report", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "55364e6d-1854-4afb-8cd8-abe250f5b36c", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Data Value Range Metrics for the column: age"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "counter", "title": "", "size": 2, "id": "2bf5b140-5189-4721-a750-77f679db6a03", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Range is from 0 to 10"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "table", "title": "Current: Values statistic", "size": 2, "id": "00bdecb1-9819-41e0-862d-1f7f815943ff", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": ["Metric", "Value"], "data": [["Values from the range", "0"], ["Share from the range", "0.0"], ["Values not in the range", "28842"], ["Share not in the range", "1.0"], ["Rows count", "28842"]]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "counter", "title": "", "size": 2, "id": "77e86d07-7811-4763-b1a5-0e19532a4c47", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Data Value Range Metrics for the column: capital-gain"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "counter", "title": "", "size": 2, "id": "08bcda42-8717-4e65-add8-582ec110295d", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Range is from 0 to 10"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "table", "title": "Current: Values statistic", "size": 2, "id": "dd856f40-a54d-40b2-9249-b7cf977b9352", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": ["Metric", "Value"], "data": [["Values from the range", "26446"], ["Share from the range", "0.917"], ["Values not in the range", "2396"], ["Share not in the range", "0.083"], ["Rows count", "28842"]]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "counter", "title": "", "size": 2, "id": "ea824fef-30b1-4ee9-a263-35f867511b11", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Data Value Range Metrics for the column: capital-loss"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "counter", "title": "", "size": 2, "id": "cf70740b-3000-401f-aa6a-5f52fe24e702", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Range is from 0 to 10"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "table", "title": "Current: Values statistic", "size": 2, "id": "e6b12d05-188e-4dd6-a9f5-e2adb2e5ede0", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": ["Metric", "Value"], "data": [["Values from the range", "27515"], ["Share from the range", "0.954"], ["Values not in the range", "1327"], ["Share not in the range", "0.046"], ["Rows count", "28842"]]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "counter", "title": "", "size": 2, "id": "3317cd31-35d8-4d9e-a776-0f8a39b249fa", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Data Value Range Metrics for the column: education-num"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "counter", "title": "", "size": 2, "id": "1a5d31f0-13b1-4bd8-ab31-67d161fc8dfb", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Range is from 0 to 10"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "tab ...
#     var additional_graphs_e
